# %%
# !pip install streamlit
#!pip install pyngrok
#!pyngrok authtoken 2CP2g7NunlOkqODTXwkyrWdcW1h_89G8agh5Sz7zrJeEDZ6ZF
# Out:
# Requirement already satisfied: streamlit in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (1.11.0)
# Requirement already satisfied: click>=7.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: attrs>=16.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (20.3.0)
# Requirement already satisfied: numpy in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (1.20.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: validators>=0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: tzlocal>=1.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (4.2)
# Requirement already satisfied: protobuf<4,>=3.12 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (3.20.1)
# Requirement already satisfied: blinker>=1.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (1.5)
# Requirement already satisfied: python-dateutil in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (2.8.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (3.10.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: altair>=3.2.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: toml in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: packaging>=14.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (20.9)
# Requirement already satisfied: requests>=2.4 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (2.25.1)
# Requirement already satisfied: pympler>=0.9 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (12.5.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (8.2.0)
# Requirement already satisfied: pandas>=0.21.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (1.2.4)
# Requirement already satisfied: pyarrow>=4.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (8.0.0)
# Requirement already satisfied: semver in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: tornado>=5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit) (6.1)
# Requirement already satisfied: jinja2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: entrypoints in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: toolz in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: jsonschema>=3.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.4->streamlit) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=14.1->streamlit) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.0->streamlit) (2021.1)
# Requirement already satisfied: ipykernel>=5.1.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: six>=1.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil->streamlit) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit) (1.26.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->streamlit) (2.8.1)
# Requirement already satisfied: backports.zoneinfo in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from tzlocal>=1.1->streamlit) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from validators>=0.2->streamlit) (5.0.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: ipython>=5.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.22.0)
# Requirement already satisfied: appnope in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: jupyter-client in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: setuptools in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (52.0.0.post20210125)
# Requirement already satisfied: ipython-genutils in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: tzdata in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit) (2022.1)
# Requirement already satisfied: pexpect>4.3 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.17.2)
# Requirement already satisfied: pickleshare in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.17)
# Requirement already satisfied: backcall in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyter-core in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.3.0)
# Requirement already satisfied: pyzmq>=13 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: nbconvert in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: argon2-cffi in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: defusedxml in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: testpath in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: bleach in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.3.0)
# Requirement already satisfied: pycparser in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: async-generator in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: webencodings in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install streamlit-lottie
# Out:
# Requirement already satisfied: streamlit-lottie in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (0.0.3)
# Requirement already satisfied: streamlit>=0.63 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit-lottie) (1.11.0)
# Requirement already satisfied: tzlocal>=1.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (4.2)
# Requirement already satisfied: tornado>=5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (4.3.0)
# Requirement already satisfied: packaging>=14.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (20.9)
# Requirement already satisfied: attrs>=16.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (20.3.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (3.20.1)
# Requirement already satisfied: pyarrow>=4.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (8.0.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (8.2.0)
# Requirement already satisfied: requests>=2.4 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (2.25.1)
# Requirement already satisfied: cachetools>=4.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (12.5.1)
# Requirement already satisfied: blinker>=1.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (1.5)
# Requirement already satisfied: click>=7.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (7.1.2)
# Requirement already satisfied: pandas>=0.21.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (1.2.4)
# Requirement already satisfied: pympler>=0.9 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (1.0.1)
# Requirement already satisfied: numpy in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (1.20.1)
# Requirement already satisfied: python-dateutil in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (2.8.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (3.10.0)
# Requirement already satisfied: validators>=0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (3.1.27)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (0.7.1)
# Requirement already satisfied: toml in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (0.10.2)
# Requirement already satisfied: altair>=3.2.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (4.2.0)
# Requirement already satisfied: semver in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.63->streamlit-lottie) (2.13.0)
# Requirement already satisfied: jinja2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (2.11.3)
# Requirement already satisfied: entrypoints in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (0.3)
# Requirement already satisfied: toolz in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (0.11.1)
# Requirement already satisfied: jsonschema>=3.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (3.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-lottie) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit-lottie) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=14.1->streamlit>=0.63->streamlit-lottie) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit-lottie) (2021.1)
# Requirement already satisfied: ipykernel>=5.1.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (7.6.3)
# Requirement already satisfied: six>=1.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil->streamlit>=0.63->streamlit-lottie) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-lottie) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-lottie) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-lottie) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-lottie) (1.26.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-lottie) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-lottie) (2.8.1)
# Requirement already satisfied: backports.zoneinfo in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-lottie) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-lottie) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from validators>=0.2->streamlit>=0.63->streamlit-lottie) (5.0.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-lottie) (5.0.0)
# Requirement already satisfied: ipython>=5.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (7.22.0)
# Requirement already satisfied: appnope in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.1.2)
# Requirement already satisfied: jupyter-client in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (6.1.12)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (3.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (0.17.3)
# Requirement already satisfied: setuptools in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-lottie) (52.0.0.post20210125)
# Requirement already satisfied: ipython-genutils in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.2.0)
# Requirement already satisfied: tzdata in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit>=0.63->streamlit-lottie) (2022.1)
# Requirement already satisfied: pickleshare in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (3.0.17)
# Requirement already satisfied: pexpect>4.3 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (4.8.0)
# Requirement already satisfied: backcall in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.2.0)
# Requirement already satisfied: jupyter-core in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (6.3.0)
# Requirement already satisfied: pyzmq>=13 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (20.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.7.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (1.5.0)
# Requirement already satisfied: nbconvert in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.10.1)
# Requirement already satisfied: argon2-cffi in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (20.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (1.14.5)
# Requirement already satisfied: jupyterlab-pygments in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (1.4.3)
# Requirement already satisfied: defusedxml in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.8.4)
# Requirement already satisfied: testpath in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.5.3)
# Requirement already satisfied: bleach in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (3.3.0)
# Requirement already satisfied: pycparser in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (2.20)
# Requirement already satisfied: async-generator in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (1.5.1)
# Requirement already satisfied: webencodings in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.63->streamlit-lottie) (0.5.1)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile app.py
import streamlit as st
from streamlit_lottie import st_lottie
import json
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
import numpy as np                                                  # Importing package numpys (For Numerical Python)
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import scipy as sp 
import warnings
warnings.filterwarnings('ignore')

pd.options.mode.chained_assignment = None  
def load_lottiefile(filepath: str):
    with open(filepath, "r") as f:
        return json.load(f)
# for data pipeline

from sklearn.model_selection import train_test_split
from sklearn.metrics import*
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.pipeline import make_pipeline


# for prediction (machine learning models) ------------------------

from sklearn.linear_model import*
from sklearn.preprocessing import*
from sklearn.ensemble import*
from sklearn.neighbors import*
from sklearn import svm
from sklearn.naive_bayes import*
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

data = pd.read_csv('avocado.csv')
data=data.drop(['Unnamed: 0'], axis=1)
X = data[['4046', '4225', '4770', 'type','region']]
Y = data['AveragePrice']
y = np.log1p(Y)
X = pd.get_dummies(X, prefix=["type","region"], columns=["type","region"], drop_first = True)

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error


X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.3, random_state = 99)
lr = LinearRegression()
lr.fit(X_train,y_train)
region_list = data['region'].unique()
type_list = data['type'].unique()

def predict(udf, selected_region,selected_type):
  udf['region_'+ selected_region][0] = 1
  udf['type_' + selected_type ][0] = 1
  ans = (np.exp(lr.predict(udf))-1)
  return ans

#streamlit   
   
st.header('Price Prediction')
lottie_coding = load_lottiefile("avocado.json")
st_lottie(
    lottie_coding,
    speed=1.5,
    reverse=False,
    loop=True,
    quality="low",height=220
)
selected_region = st.selectbox(
    "Select a region from the dropdown",
    region_list
)
selected_type = st.selectbox(
    "Select a Type from the dropdown",
    type_list
)
if st.button('Show Price'):
  dict_map = {}
  for idx, key in enumerate(X_train.columns):
    dict_map[key] = idx
  user_data = {key:[0] for key in X_train.columns}
  udf=pd.DataFrame(user_data)
  ans = predict(udf, selected_region, selected_type)
  st.write(ans)
st.write('  '
         )
st.write(' ')
# Out:
# Overwriting app.py

# %%
#!streamlit run app.py &>/dev/null&
# !pip install pipreqs
# !streamlit run app.py & npx localtunnel --port 8501
#from pyngrok import ngrok
#ngrok config add-authtoken 2CP2g7NunlOkqODTXwkyrWdcW1h_89G8agh5Sz7zrJeEDZ6ZF
#Setup a tunnel to the streamlit port 8501
#public_url = ngrok.connect(port='8501')
#public_url
# Out:
# Requirement already satisfied: pipreqs in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (0.4.11)
# Requirement already satisfied: docopt in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pipreqs) (0.6.2)
# Requirement already satisfied: yarg in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from pipreqs) (0.1.9)
# Requirement already satisfied: requests in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from yarg->pipreqs) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg->pipreqs) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg->pipreqs) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg->pipreqs) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg->pipreqs) (2.10)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Need to install the following packages:
#   localtunnel
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://192.168.2.182:8502
#
# 2022-07-24 17:32:04.855 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'type_conventional'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/streamlit/scriptrunner/script_runner.py", line 557, in _run_script
#     exec(code, module.__dict__)
#   File "app.py", line 90, in <module>
#     ans = predict(udf, selected_region, selected_type)
#   File "app.py", line 61, in predict
#     udf['type_' + selected_type ][0] = 1
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'type_conventional'
# 2022-07-24 17:33:04.452 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'type_conventional'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/streamlit/scriptrunner/script_runner.py", line 557, in _run_script
#     exec(code, module.__dict__)
#   File "app.py", line 90, in <module>
#     ans = predict(udf, selected_region, selected_type)
#   File "app.py", line 61, in predict
#     udf['type_' + selected_type ][0] = 1
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'type_conventional'
# 2022-07-24 17:33:48.141 Uncaught app exception
# Traceback (most recent call last):
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3080, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4554, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4562, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'type_conventional'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/streamlit/scriptrunner/script_runner.py", line 557, in _run_script
#     exec(code, module.__dict__)
#   File "app.py", line 90, in <module>
#     ans = predict(udf, selected_region, selected_type)
#   File "app.py", line 61, in predict
#     udf['type_' + selected_type ][0] = 1
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py", line 3024, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/Users/mylenetu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py", line 3082, in get_loc
#     raise KeyError(key) from err
# KeyError: 'type_conventional'
